# %% [markdown]
# We just build the following URL in an exercise:
#
# https://erddap.bco-dmo.org/erddap/tabledap/bcodmo_dataset_815732.csv?Cruise_ID,Cast_ID,Station_ID,UTC_Date,UTC_Time,time,latitude,longitude,depth,Strain_Gauge_Pressure,Conductivity,Salinity,Temperature,Potential_Temp,Density,Sigma_theta,Oxygen_mLL,Oxygen_pcnt,PAR_Irradiance,ISUS,flag
#
# Let's now download it with python to our computer locally

# %% [markdown]
# The urllib library is part of the erddapy package that you have installed. Import this package into the Python environment  to work with url's in your environment

# %%
# Import the urllib library
import urllib.request

# %%
#define the url you want to download
download_url = "https://erddap.bco-dmo.org/erddap/tabledap/bcodmo_dataset_815732.csv?Cruise_ID,Cast_ID,Station_ID,UTC_Date,UTC_Time,time,latitude,longitude,depth,Strain_Gauge_Pressure,Conductivity,Salinity,Temperature,Potential_Temp,Density,Sigma_theta,Oxygen_mLL,Oxygen_pcnt,PAR_Irradiance,ISUS,flag"
    
# Define where you want to save the file on your computer
name_to_save = "bcodmo_dataset_815732.csv"

# download the dataset   
urllib.request.urlretrieve(download_url, name_to_save)
# Out:
# ('bcodmo_dataset_815732.csv', <http.client.HTTPMessage at 0x1c6f1202250>)

# %% [markdown]
# Import the **Pandas library** to work with tables in your Python environment.

# %%
# Import the downloaded .csv data into jupyter notebooks with the package Pandas
import pandas as pd

# %%
dataframe = pd.read_csv ("bcodmo_dataset_815732.csv", dtype='unicode')
dataframe
# Out:
#        Cruise_ID   Cast_ID Station_ID    UTC_Date  UTC_Time  \
# 0       unitless  unitless   unitless    unitless  unitless
# 1      SAV-15-04         1         12  03/16/2015  15:56:47
# 2      SAV-15-04         1         12  03/16/2015  15:56:47
# 3      SAV-15-04         1         12  03/16/2015  15:56:47
# 4      SAV-15-04         1         12  03/16/2015  15:56:47
# ...          ...       ...        ...         ...       ...
# 49695  SAV-17-02       314        21a  01/27/2017  20:46:05
# 49696  SAV-17-02       314        21a  01/27/2017  20:46:05
# 49697  SAV-17-02       314        21a  01/27/2017  20:46:05
# 49698  SAV-17-02       314        21a  01/27/2017  20:46:05
# 49699  SAV-17-02       314        21a  01/27/2017  20:46:05
#
#                        time       latitude     longitude  depth  \
# 0                       UTC  degrees_north  degrees_east      m
# 1      2015-03-16T15:56:47Z      31.032117    -76.343633    2.0
# 2      2015-03-16T15:56:47Z      31.032117    -76.343633    3.0
# 3      2015-03-16T15:56:47Z      31.032117    -76.343633    4.0
# 4      2015-03-16T15:56:47Z      31.032117    -76.343633    5.0
# ...                     ...            ...           ...    ...
# 49695  2017-01-27T20:46:05Z      31.310092      -79.7353  152.0
# 49696  2017-01-27T20:46:05Z      31.310092      -79.7353  153.0
# 49697  2017-01-27T20:46:05Z      31.310092      -79.7353  154.0
# 49698  2017-01-27T20:46:05Z      31.310092      -79.7353  155.0
# 49699  2017-01-27T20:46:05Z      31.310092      -79.7353  156.0
#
#       Strain_Gauge_Pressure  ... Salinity      Temperature   Potential_Temp  \
# 0                       psi  ...      PSU  degrees Celsius  degrees Celsius
# 1                     2.921  ...  36.5412          22.7349          22.7344
# 2                     4.381  ...  36.5415          22.7392          22.7386
# 3                     5.841  ...  36.5436          22.7064          22.7055
# 4                     7.302  ...  36.5394           22.712          22.7108
# ...                     ...  ...      ...              ...              ...
# 49695               222.074  ...  35.5017          11.7805          11.7606
# 49696               223.535  ...  35.4997          11.7749          11.7549
# 49697               224.997  ...  35.4951          11.7661          11.7461
# 49698               226.459  ...  35.4872          11.7474          11.7272
# 49699               227.919  ...  35.4823          11.7465          11.7263
#
#                                   Density                         Sigma_theta  \
# 0      kilograms per cubic meter (kg/m^3)  kilograms per cubic meter (kg/m^3)
# 1                               1025.1888                             25.1799
# 2                               1025.1911                             25.1789
# 3                                1025.209                               25.19
# 4                               1025.2093                             25.1853
# ...                                   ...                                 ...
# 49695                           1027.7071                             27.0246
# 49696                           1027.7112                             27.0242
# 49697                           1027.7138                             27.0223
# 49698                           1027.7158                             27.0198
# 49699                           1027.7166                             27.0161
#
#                          Oxygen_mLL         Oxygen_pcnt PAR_Irradiance  \
# 0      milliliters per liter (ml/l)  unitless (percent)       unitless
# 1                            4.7443              97.152         1417.0
# 2                            4.7534              97.346         259.74
# 3                            4.7443              97.105         210.45
# 4                            4.7428              97.083         191.19
# ...                             ...                 ...            ...
# 49695                        2.8551              47.113         0.0115
# 49696                        2.8515              47.046         0.0108
# 49697                        2.8514              47.036           0.01
# 49698                        2.8444                46.9         0.0094
# 49699                         2.847              46.939         0.0093
#
#              ISUS      flag
# 0           volts  unitless
# 1      -4.8674568       0.0
# 2      -4.8642149       0.0
# 3      -4.8669887       0.0
# 4      -4.8669928       0.0
# ...           ...       ...
# 49695   31.677982       0.0
# 49696   32.199062       0.0
# 49697   33.336456       0.0
# 49698   32.742559       0.0
# 49699   38.333281       0.0
#
# [49700 rows x 21 columns]
